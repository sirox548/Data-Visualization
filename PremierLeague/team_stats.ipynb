# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# path to read file
file_path = './teamstats-1920.csv'

# Read file
teamstats = pd.read_csv(file_path, index_col='Squad')

# %%
teamstats.head()
# Out:
#              # Pl  Poss  MP  Starts   Min  Gls  Ast  PK  PKatt  CrdY  ...  \
# Squad                                                                 ...
# Arsenal        29  54.0  38     418  3420   56   35   3      3    88  ...
# Aston Villa    28  43.9  38     418  3420   40   32   1      3    70  ...
# Bournemouth    27  43.8  38     418  3420   38   24   4      4    78  ...
# Brighton       25  52.2  38     418  3420   35   24   1      2    59  ...
# Burnley        22  41.4  38     418  3420   41   30   3      3    67  ...
#
#              G-PK Per 90 Minutes  G+A-PK Per 90 Minutes    xG  npxG    xA  \
# Squad
# Arsenal                     1.39                   2.32  49.2  46.9  29.9
# Aston Villa                 1.03                   1.87  40.0  37.6  30.4
# Bournemouth                 0.89                   1.53  42.7  39.7  27.4
# Brighton                    0.89                   1.53  41.2  39.7  26.5
# ...

# %%
teamstats.tail()
# Out:
#              # Pl  Poss  MP  Starts   Min  Gls  Ast  PK  PKatt  CrdY  ...  \
# Squad                                                                 ...
# Southampton    25  49.3  38     418  3420   51   32   2      5    55  ...
# Tottenham      29  52.2  38     418  3420   56   39   3      4    84  ...
# Watford        26  42.5  38     418  3420   35   21   7      8    80  ...
# West Ham       29  44.0  38     418  3420   49   36   4      4    64  ...
# Wolves         21  48.3  38     418  3420   49   34   4      4    61  ...
#
#              G-PK Per 90 Minutes  G+A-PK Per 90 Minutes    xG  npxG    xA  \
# Squad
# Southampton                 1.29                   2.13  53.9  50.0  31.4
# Tottenham                   1.39                   2.42  46.1  43.0  30.8
# Watford                     0.74                   1.29  45.1  39.1  28.2
# West Ham                    1.18                   2.13  46.2  43.2  31.8
# ...

# %%
teamstats.describe()
# Out:
#             # Pl      Poss    MP  Starts     Min         Gls        Ast  \
# count  20.000000  20.00000  20.0    20.0    20.0   20.000000  20.000000
# mean   26.100000  50.05500  38.0   418.0  3420.0   50.100000  35.300000
# std     2.531902   7.79902   0.0     0.0     0.0   18.806214  14.183385
# min    21.000000  38.60000  38.0   418.0  3420.0   25.000000  18.000000
# 25%    24.000000  43.87500  38.0   418.0  3420.0   37.500000  24.750000
# 50%    26.000000  49.25000  38.0   418.0  3420.0   45.500000  32.000000
# 75%    28.250000  54.55000  38.0   418.0  3420.0   58.250000  40.000000
# max    30.000000  66.90000  38.0   418.0  3420.0  100.000000  69.000000
#
#               PK      PKatt       CrdY  ...  G-PK Per 90 Minutes  \
# count  20.000000  20.000000  20.000000  ...            20.000000
# mean    3.600000   4.600000  65.950000  ...             1.222500
# std     2.521487   3.377947  12.343654  ...             0.460102
# ...

# %%
list(teamstats.columns)
# Out:
# ['# Pl',
#  'Poss',
#  'MP',
#  'Starts',
#  'Min',
#  'Gls',
#  'Ast',
#  'PK',
#  'PKatt',
#  'CrdY',
#  'CrdR',
#  'Gls Per 90 Minutes',
#  'Ast Per 90 Minutes',
#  'G+A Per 90 Minutes',
#  'G-PK Per 90 Minutes',
#  'G+A-PK Per 90 Minutes',
#  'xG',
#  'npxG',
#  'xA',
#  'xG Per 90 Minutes',
#  'xA Per 90 Minutes',
#  'xG+xA Per 90 Minutes',
#  'npxG Per 90 Minutes',
#  'npxG+xA Per 90 Minutes']

# %% [markdown]
# # line plot showing rate of goals score every 90 minutes per number of assist.

# %%
plt.figure(figsize=(14,6))
plt.title('Premier league teams Goals per 90 Minutes')
sns.lineplot(data=teamstats['Gls Per 90 Minutes'], label='Gls Per 90 Minutes')
sns.lineplot(data=teamstats['Ast Per 90 Minutes'], label='Ast Per 90 Minutes')
plt.xlabel('Number of Goal per Assist.')
# Out:
# Text(0.5, 0, 'Number of Goal per Assist.')

# %% [markdown]
# # bar plot showing rate of goals score every 90 minutes per number of assist.

# %%
# width and height of chart
plt.figure(figsize=(14,10))

# Title
plt.title('Barplot showing the Yellow Card of each premier league team')
# barplot of teams that accumulated the most yellow cards
sns.barplot(y=teamstats.index, x=teamstats['CrdY'])

# %%
# width and height of chart
plt.figure(figsize=(14,10))

# Title
plt.title('Barplot showing the Red Card of each premier league team')
# barplot of teams that accumulated the most yellow cards
sns.barplot(y=teamstats.index, x=teamstats['CrdR'])

### Arsenal are the most undisplined team with the most red card offense and yellow card offense

# %% [markdown]
# ### Arsenal are the most undisplined team with the most red card offense and yellow card offense
