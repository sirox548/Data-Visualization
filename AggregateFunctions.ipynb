# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Loading CSV or XLSX File

# %%
# Loading car loan data from csv file

filename = 'Files/car_financing.csv'
df = pd.read_csv(filename)

#df = pd.read_excel(filename)

# %%
df
# Out:
#      Month  Starting Balance  Repayment  Interest Paid  Principal Paid  \
# 0        1          34689.96     687.23         202.93          484.30
# 1        2          34205.66     687.23         200.10          487.13
# 2        3          33718.53     687.23         197.25          489.98
# 3        4          33228.55     687.23         194.38          492.85
# 4        5          32735.70     687.23         191.50          495.73
# ..     ...               ...        ...            ...             ...
# 403     56           3951.11     796.01           9.54          786.47
# 404     57           3164.64     796.01           7.64          788.37
# 405     58           2376.27     796.01           5.74          790.27
# 406     59           1586.00     796.01           3.83          792.18
# 407     60            793.82     796.01           1.91          794.10
#
#      New Balance  term  interest_rate       car_type
# 0       34205.66    60         0.0702  Toyota Sienna
# ...

# %% [markdown]
# # selecting columns using brackets

# %%
# Selecting one column using double brackets
df[['car_type']].head()
# Out:
#         car_type
# 0  Toyota Sienna
# 1  Toyota Sienna
# 2  Toyota Sienna
# 3  Toyota Sienna
# 4  Toyota Sienna

# %%
df['car_type'].sum()
# Out:
# 'Toyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota SiennaToyota Sienna'

# %%
# Selecting multiple columns using double brackets
df[['Interest Paid', 'interest_rate']].head()
# Out:
#    Interest Paid  interest_rate
# 0         202.93         0.0702
# 1         200.10         0.0702
# 2         197.25         0.0702
# 3         194.38         0.0702
# 4         191.50         0.0702

# %% [markdown]
# # Pandas Slicing

# %%
# Using panda series for slicing => [starting index : ending index ]
df['car_type']
# Out:
# 0      Toyota Sienna
# 1      Toyota Sienna
# 2      Toyota Sienna
# 3      Toyota Sienna
# 4      Toyota Sienna
#            ...
# 403        VW Golf R
# 404        VW Golf R
# 405        VW Golf R
# 406        VW Golf R
# 407        VW Golf R
# Name: car_type, Length: 408, dtype: object

# %%
df['car_type'][0:10]
# Out:
# 0    Toyota Sienna
# 1    Toyota Sienna
# 2    Toyota Sienna
# 3    Toyota Sienna
# 4    Toyota Sienna
# 5    Toyota Sienna
# 6    Toyota Sienna
# 7    Toyota Sienna
# 8    Toyota Sienna
# 9    Toyota Sienna
# Name: car_type, dtype: object

# %%
# Selecting column using double brackets
df['car_type']
# Out:
# 0      Toyota Sienna
# 1      Toyota Sienna
# 2      Toyota Sienna
# 3      Toyota Sienna
# 4      Toyota Sienna
#            ...
# 403        VW Golf R
# 404        VW Golf R
# 405        VW Golf R
# 406        VW Golf R
# 407        VW Golf R
# Name: car_type, Length: 408, dtype: object

# %% [markdown]
# # Filtering

# %%
# Viewing the count of repeated values in a single column
df['car_type'].value_counts()
# Out:
# VW Golf R         144
# Toyota Sienna     120
# Toyota Carolla    111
# Toyota Corolla     33
# Name: car_type, dtype: int64

# %%
# filtering produces a pandas series of True or False values
car_filter = df['car_type'] == 'Toyota Sienna'

# %%
car_filter.head()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: car_type, dtype: bool

# %%
df.loc[car_filter, :].head()
# Out:
#    Month  Starting Balance  Repayment  Interest Paid  Principal Paid  \
# 0      1          34689.96     687.23         202.93          484.30
# 1      2          34205.66     687.23         200.10          487.13
# 2      3          33718.53     687.23         197.25          489.98
# 3      4          33228.55     687.23         194.38          492.85
# 4      5          32735.70     687.23         191.50          495.73
#
#    New Balance  term  interest_rate       car_type
# 0     34205.66    60         0.0702  Toyota Sienna
# 1     33718.53    60         0.0702  Toyota Sienna
# 2     33228.55    60         0.0702  Toyota Sienna
# 3     32735.70    60         0.0702  Toyota Sienna
# 4     32239.97    60         0.0702  Toyota Sienna

# %%
df = df.loc[car_filter, :]

# %%
df
# Out:
#      Month  Starting Balance  Repayment  Interest Paid  Principal Paid  \
# 0        1          34689.96     687.23         202.93          484.30
# 1        2          34205.66     687.23         200.10          487.13
# 2        3          33718.53     687.23         197.25          489.98
# 3        4          33228.55     687.23         194.38          492.85
# 4        5          32735.70     687.23         191.50          495.73
# ..     ...               ...        ...            ...             ...
# 115     56           3133.83     632.47           9.37          623.10
# 116     57           2510.73     632.47           7.51          624.96
# 117     58           1885.77     632.47           5.64          626.83
# 118     59           1258.94     632.47           3.76          628.71
# 119     60            630.23     632.47           1.88          630.59
#
#      New Balance  term  interest_rate       car_type
# 0       34205.66    60         0.0702  Toyota Sienna
# ...

# %%
df['interest_rate'].value_counts()
# Out:
# 0.0702    60
# 0.0359    60
# Name: interest_rate, dtype: int64

# %%
# To filter interest rate of 0.0702
df['interest_rate'] == 0.0702
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 115    False
# 116    False
# 117    False
# 118    False
# 119    False
# Name: interest_rate, Length: 120, dtype: bool

# %%
filter_interest = df['interest_rate'] == 0.0702

# %%
df = df.loc[filter_interest, :]

# %%
df['interest_rate'].value_counts()
# Out:
# 0.0702    60
# Name: interest_rate, dtype: int64

# %%
# Combining two filters
df.loc[car_filter & filter_interest, :].head(10)
# Out:
#    Month  Starting Balance  Repayment  Interest Paid  Principal Paid  \
# 0      1          34689.96     687.23         202.93          484.30
# 1      2          34205.66     687.23         200.10          487.13
# 2      3          33718.53     687.23         197.25          489.98
# 3      4          33228.55     687.23         194.38          492.85
# 4      5          32735.70     687.23         191.50          495.73
# 5      6          32239.97     687.23         188.60          498.63
# 6      7          31741.34     687.23         185.68          501.55
# 7      8          31239.79     687.23         182.75          504.48
# 8      9          30735.31     687.23         179.80          507.43
# 9     10          30227.88     687.23         176.83          510.40
#
#    New Balance  term  interest_rate       car_type
# 0     34205.66    60         0.0702  Toyota Sienna
# 1     33718.53    60         0.0702  Toyota Sienna
# 2     33228.55    60         0.0702  Toyota Sienna
# ...

# %% [markdown]
# # Renaming Columns

# %%
df = df.rename(columns = {
    'Starting Balance': 'starting_balance',
    'Interest Paid': 'interest_paid',
    'Principal Paid': 'principal_paid',
    'New Balance': 'new_balance'
})

# %%
df.head()
# Out:
#    Month  starting_balance  Repayment  interest_paid  principal_paid  \
# 0      1          34689.96     687.23         202.93          484.30
# 1      2          34205.66     687.23         200.10          487.13
# 2      3          33718.53     687.23         197.25          489.98
# 3      4          33228.55     687.23         194.38          492.85
# 4      5          32735.70     687.23         191.50          495.73
#
#    new_balance  term  interest_rate       car_type
# 0     34205.66    60         0.0702  Toyota Sienna
# 1     33718.53    60         0.0702  Toyota Sienna
# 2     33228.55    60         0.0702  Toyota Sienna
# 3     32735.70    60         0.0702  Toyota Sienna
# 4     32239.97    60         0.0702  Toyota Sienna

# %%
df.columns
# Out:
# Index(['Month', 'starting_balance', 'Repayment', 'interest_paid',
#        'principal_paid', 'new_balance', 'term', 'interest_rate', 'car_type'],
#       dtype='object')

# %% [markdown]
# # Statistical calculations

# %%
# Finding the sum of values in a column
df['interest_paid'].sum()
# Out:
# 6543.509999999999

# %%
# Sum of values across all columns
df.sum()
# Out:
# Month                                                            1830
# starting_balance                                           1.1186e+06
# Repayment                                                     41233.8
# interest_paid                                                 6543.51
# principal_paid                                                34690.3
# new_balance                                               1.08391e+06
# term                                                             3600
# interest_rate                                                   4.212
# car_type            Toyota SiennaToyota SiennaToyota SiennaToyota ...
# dtype: object

# %% [markdown]
# ## Finding Missing Values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60 entries, 0 to 59
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Month             60 non-null     int64
#  1   starting_balance  60 non-null     float64
#  2   Repayment         60 non-null     float64
#  3   interest_paid     60 non-null     float64
#  4   principal_paid    60 non-null     float64
#  5   new_balance       60 non-null     float64
#  6   term              60 non-null     int64
#  7   interest_rate     60 non-null     float64
#  8   car_type          60 non-null     object
# dtypes: float64(6), int64(2), object(1)
# memory usage: 4.7+ KB

# %%
# Pandas Series of True and False Values
df['interest_paid'].isna().head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: interest_paid, dtype: bool

# %%
# Finding number of missing valuse or data
df['interest_paid'].isna().sum()
# Out:
# 0

# %% [markdown]
# ## Removing NA or null values

# %%
# Drop all NA or missing values in all the columns in the datass
df.dropna(how = 'any')
# Out:
#     Month  starting_balance  Repayment  interest_paid  principal_paid  \
# 0       1          34689.96     687.23         202.93          484.30
# 1       2          34205.66     687.23         200.10          487.13
# 2       3          33718.53     687.23         197.25          489.98
# 3       4          33228.55     687.23         194.38          492.85
# 4       5          32735.70     687.23         191.50          495.73
# 5       6          32239.97     687.23         188.60          498.63
# 6       7          31741.34     687.23         185.68          501.55
# 7       8          31239.79     687.23         182.75          504.48
# 8       9          30735.31     687.23         179.80          507.43
# 9      10          30227.88     687.23         176.83          510.40
# 10     11          29717.48     687.23         173.84          513.39
# 11     12          29204.09     687.23         170.84          516.39
# ...

# %% [markdown]
# ## Filiing in Missing Vaues

# %% [raw]
# Search for missing values by columns

# %%
# Fill NaN with zeros { if nan is recorded between row 30 to 39}
df['interest_paid'][30:40].fillna(0)
# Out:
# 30    110.32
# 31    106.94
# 32    103.55
# 33    100.13
# 34     96.70
# 35     93.24
# 36     89.77
# 37     86.27
# 38     82.76
# 39     79.22
# Name: interest_paid, dtype: float64

# %%
# Back Fill in Values
df['interest_paid'][30:40].fillna(method='bfill')
# Out:
# 30    110.32
# 31    106.94
# 32    103.55
# 33    100.13
# 34     96.70
# 35     93.24
# 36     89.77
# 37     86.27
# 38     82.76
# 39     79.22
# Name: interest_paid, dtype: float64

# %%
# Forward Fill in Values
df['interest_paid'][30:40].fillna(method='ffill')
# Out:
# 30    110.32
# 31    106.94
# 32    103.55
# 33    100.13
# 34     96.70
# 35     93.24
# 36     89.77
# 37     86.27
# 38     82.76
# 39     79.22
# Name: interest_paid, dtype: float64

# %%
# Using Linear Interpolation (fill in the average values between the missing values in the NaN row or 0 value row
df['interest_paid'][30:40].interpolate(method='linear')
# Out:
# 30    110.32
# 31    106.94
# 32    103.55
# 33    100.13
# 34     96.70
# 35     93.24
# 36     89.77
# 37     86.27
# 38     82.76
# 39     79.22
# Name: interest_paid, dtype: float64
